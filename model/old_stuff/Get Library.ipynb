# %%
from process_data import *
import os

# %%
folder_name = "converted_data_libri_akuan"
reg_expr = r"^(libri.*)\.id$"
pre_abs_batch_names = get_names(folder_name, reg_expr)

# %%
batch_names = [os.path.join(folder_name, batch_name) for batch_name in pre_abs_batch_names]

# %%
lib_batch_num = 1
current_batch_mfes = []
current_batch_phonemes = []
current_batch_ids = []
lib_batch_len = 100
lib_folder = "test_lib"
stem = "lib_stem"

# %%
while batch_names:
    -
# Out:
# Finished lib batch number 1
# Finished lib batch number 2
# Finished lib batch number 3
# Finished lib batch number 4
# Finished lib batch number 5
# Finished lib batch number 6
# Finished lib batch number 7
# Finished lib batch number 8
# Finished lib batch number 9
# Finished lib batch number 10
# Finished lib batch number 11
# Finished lib batch number 12
# Finished lib batch number 13
# Finished lib batch number 14
# Finished lib batch number 15
# Finished lib batch number 16
# Finished lib batch number 17
# Finished lib batch number 18
# Finished lib batch number 19
# Finished lib batch number 20
# Finished lib batch number 21
# Finished lib batch number 22
# Finished lib batch number 23
# Finished lib batch number 24
# Finished lib batch number 25
# Finished lib batch number 26
# Finished lib batch number 27
# Finished lib batch number 28
# Finished lib batch number 29
# Finished lib batch number 30
# Finished lib batch number 31
# Finished lib batch number 32
# ...
