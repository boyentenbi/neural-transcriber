# %%
from copy import deepcopy
import nltk
import numpy as np
import MultiTree as MT

# %%
MT.tuple_list
# Out:
# [([u'S', u'T', u'AY', u'N', u'B', u'ER', u'G', u'ER'], [u'steinberger']),
#  ([u'B', u'EH', u'L', u'V', u'Y', u'UW'], [u'bellevue']),
#  ([u'S', u'W', u'IH', u'N', u'T', u'AH', u'N'], [u'swinton']),
#  ([u'AE', u'M', u'D', u'EH', u'K'], [u'amdek', u'amdec']),
#  ([u'B', u'AA', u'D', u'IY', u'Z'], [u'bodies', u"body's"]),
#  ([u'HH', u'AE', u'K', u'AH', u'N'], [u'hakon']),
#  ([u'OW', u'P', u'EH', u'K'], [u'opec']),
#  ([u'OW', u'P', u'EH', u'R'], [u'opere']),
#  ([u'JH', u'EH', u'F', u'R', u'IY', u'Z'],
#   [u'jeffries', u"jeffrey's", u"geoffrey's", u'jeffreys', u'jefferies']),
#  ([u'M', u'EH', u'N', u'AH', u'N', u'AY', u'T', u'S'], [u'mennonites']),
#  ([u'P', u'AY', u'N', u'T', u'ER'], [u'pinter']),
#  ([u'AH', u'N', u'IH', u'SH', u'UW', u'D'], [u'unissued']),
#  ([u'L', u'AO', u'D', u'Z'], [u'lauds']),
#  ([u'B', u'EH', u'CH', u'ER'], [u'betcher']),
#  ([u'AA', u'TH', u'M', u'AH', u'N'], [u'othman']),
#  ([u'P', u'R', u'IH', u'D', u'IH', u'K', u'AH', u'M', u'AH', u'N', u'T'],
#   [u'predicament']),
#  ([u'M', u'AE', u'S', u'T', u'ER', u'B', u'EY', u'SH', u'AH', u'N'],
#   [u'masterbation', u'masturbation']),
#  ([u'W', u'AA', u'T', u'AH', u'L', u'D'], [u'wattled']),
#  ([u'S', u'AY', u'F', u'ER', u'T'], [u'seifert', u'cyphert', u'seiffert']),
#  ([u'AY', u'AA', u'N', u'IH', u'K', u'S'], [u'ionics']),
#  ([u'S', u'UW', u'CH', u'IH', u'N', u'D', u'AH'], [u'suchinda']),
#  ([u'S', u'AA', u'V', u'R', u'AH', u'N', u'T', u'IY'], [u'sovereignty']),
#  ([u'W', u'EH', u'R', u'HH', u'AW', u'S'], [u'wearhouse', u'warehouse']),
#  ([u'S', u'AY', u'F', u'ER', u'Z'], [u'scifres', u'sifers', u'cyphers']),
#  ([u'K', u'IH', u'NG', u'G', u'Z', u'W', u'EH', u'L'], [u'kingswell']),
#  ([u'K', u'AA', u'N', u'S', u'IH', u'S'], [u'consis']),
#  ([u'S', u'AA', u'K', u'UH', u'R', u'AA', u'IY'], [u'sakurai']),
#  ([u'S', u'AE', u'R', u'AH', u'JH'], [u'sarage']),
#  ([u'F', u'AA', u'IH', u'S', u'T'], [u'faist']),
#  ([u'L', u'AE', u'T', u'S'], [u'latz']),
#  ([u'OW', u'V', u'ER', u'T', u'EY', u'K', u'IH', u'NG'], [u'overtaking']),
#  ([u'K', u'L', u'OW', u'K', u'T'], [u'cloaked']),
#  ([u'AE', u'M', u'W', u'EY'], [u'amway']),
#  ([u'D', u'R', u'AE', u'M'], [u'dram']),
#  ([u'M', u'EH', u'T', u'IH', u'V', u'IY', u'ER'], [u'metivier']),
#  ([u'D', u'R', u'AE', u'B'], [u'drab']),
#  ([u'L', u'AA', u'M', u'IH', u'R', u'AA', u'N', u'D', u'IY'], [u'lamirande']),
#  ([u'D', u'R', u'AE', u'G'], [u'drag']),
#  ([u'TH', u'IY', u'ER'], [u'thier']),
#  ([u'V', u'IY', u'EH', u'T', u'N', u'AA', u'M'], [u'vietnam']),
#  ([u'S', u'EH', u'G', u'ER', u'IH', u'S', u'T'], [u'segrest']),
#  ([u'M', u'AH', u'L', u'EY', u'ZH', u'AH', u'N', u'Z'], [u'malaysians']),
#  ([u'G', u'L', u'EY', u'Z', u'AH', u'Z'], [u'glazes']),
#  ([u'JH', u'AH', u'G', u'AH', u'L'], [u'juggle']),
#  ([u'W', u'EH', u'L', u'SH'], [u'welsch']),
#  ([u'D', u'IH', u'N', u'IH', u'R', u'OW'], [u'deniro']),
#  ([u'K', u'AH', u'Z'], [u"'cause"]),
#  ([u'D', u'EH', u'N', u'T', u'AH', u'S', u'T', u'S'], [u'dentists']),
#  ([u'SH', u'AA', u'ER'], [u'schaer']),
#  ([u'G', u'AA', u'R', u'D', u'AH', u'N', u'D'], [u'gardened']),
#  ([u'K', u'AH', u'P'], [u'cupp', u'cup']),
#  ([u'R', u'AA', u'K', u'W', u'EH', u'L', u'Z'], [u"rockwell's"]),
#  ([u'K', u'AH', u'S'], [u'kus', u'cus', u'kuss', u'cuss']),
#  ([u'M', u'AE', u'N', u'T', u'AY'], [u'mantei']),
#  ([u'IH', u'N', u'S', u'IH', u'N', u'ER', u'EY', u'T', u'IH', u'D'],
#   [u'incinerated']),
#  ([u'IH', u'TH', u'AH', u'K', u'AH'], [u'ithaca']),
#  ([u'K', u'AH', u'K'], [u'kuk', u'kuc', u'kuck']),
#  ([u'K', u'AH', u'L'], [u'cull', u'cul', u'kull', u'kuhl']),
#  ([u'K', u'AH', u'M'], [u'kumm', u'cum', u'come']),
#  ([u'K', u'AH', u'N'], [u'kun', u'kuhne']),
#  ([u'B', u'AA', u'D', u'IY', u'D'], [u'bodied']),
#  ([u'S',
#    u'T',
#    u'AA',
#    u'K',
#    u'B',
#    u'R',
#    u'OW',
#    u'K',
#    u'ER',
#    u'IH',
#    u'JH',
#    u'IH',
#    u'Z'],
#   [u'stockbrokerages']),
#  ([u'V', u'AE', u'L', u'AH', u'N', u'T', u'IY', u'N', u'IY'], [u'valentini']),
#  ([u'V', u'AE', u'L', u'IH', u'N', u'T', u'IY', u'N', u'AH'], [u'valentina']),
#  ([u'K', u'AH', u'D'], [u'cudd']),
#  ([u'M', u'AE', u'N', u'T', u'AH'], [u'manta']),
#  ([u'K', u'AH', u'F'], [u'cuffe', u'cuff']),
#  ([u'N', u'EH', u'CH', u'IY', u'B', u'AH'], [u'nechyba']),
#  ([u'S', u'K', u'IY', u'P', u'AA', u'N', u'IY'], [u'schipani']),
#  ([u'AH', u'N', u'T', u'UW'], [u'unto']),
#  ([u'SH', u'AO', u'R', u'IY'], [u'shorey']),
#  ([u'M', u'AE', u'NG', u'K', u'ER'], [u'manker']),
#  ([u'P', u'R', u'AY', u'V', u'AH', u'T', u'L', u'IY'], [u'privately']),
#  ([u'HH', u'EH', u'R', u'AH', u'D'], [u'harrod', u'herod', u'herrod']),
#  ([u'V', u'AE', u'N', u'D', u'ER', u'V', u'IY', u'N'], [u'vanderveen']),
#  ([u'S', u'AA', u'K', u'AA', u'T', u'AH'], [u'sakata']),
#  ([u'K', u'EH', u'N', u'W', u'ER', u'D'], [u'kenward']),
#  ([u'HH', u'EH', u'R', u'AH', u'Z'], [u"harrah's"]),
#  ([u'B', u'ER', u'L', u'AA', u'T', u'S'], [u'berlottes']),
#  ([u'IH', u'N', u'EH', u'L', u'IH', u'JH', u'AH', u'B', u'AH', u'L'],
#   [u'ineligible']),
#  ([u'HH', u'EH', u'R', u'AH', u'P'], [u'harrop']),
#  ([u'S', u'EH', u'L', u'D', u'IH', u'N'], [u'seldin']),
#  ([u'M', u'AE', u'L', u'M', u'K', u'W', u'IH', u'S', u'T'], [u'malmquist']),
#  ([u'P',
#    u'AA',
#    u'N',
#    u'T',
#    u'IH',
#    u'F',
#    u'AH',
#    u'K',
#    u'EY',
#    u'T',
#    u'IH',
#    u'D'],
#   [u'pontificated']),
#  ([u'D', u'IH', u'F', u'Y', u'UW', u'ZH', u'AH', u'N'], [u'diffusion']),
#  ([u'AA', u'L', u'S', u'T', u'R', u'AH', u'N', u'D'], [u'ahlstrand']),
#  ([u'P', u'AA', u'P', u'IY'], [u'poppy']),
#  ([u'L', u'IH', u'G', u'AH', u'M', u'AH', u'N', u'T', u'S'], [u'ligaments']),
#  ([u'F', u'R', u'AE', u'T', u'ER', u'N', u'AY', u'Z', u'IH', u'NG'],
#   [u'fraternizing']),
#  ([u'D', u'IH', u'P', u'AO', u'R', u'T'], [u'deport']),
#  ([u'S', u'W', u'AA', u'HH', u'IY', u'L', u'IY'], [u'swahili']),
#  ([u'V', u'EH', u'R', u'IH', u'G', u'EY', u'T'], [u'variegate']),
#  ([u'D', u'R', u'EH', u'D', u'F', u'AH', u'L', u'IY'], [u'dreadfully']),
#  ([u'L', u'AY', u'ER'], [u'liar', u'leier']),
#  ([u'T', u'IY', u'V', u'Z'], [u'teves']),
#  ([u'L', u'IH', u'V', u'AH', u'N', u'D', u'AW', u'S', u'K', u'IY'],
#   [u'levandoski']),
#  ([u'HH', u'ER', u'EH', u'D', u'AH', u'T', u'IY'], [u'heredity']),
#  ([u'D', u'IH', u'JH', u'EH', u'N', u'AA', u'R', u'OW'],
#   [u'digennaro', u'degennaro']),
#  ([u'EH', u'N', u'V', u'OW', u'S'], [u'envos']),
#  ([u'S', u'W', u'IY', u'G', u'AA', u'R', u'T'], [u'sweigart']),
#  ([u'V', u'AY', u'AH', u'L', u'IH', u'N'], [u'violin']),
#  ([u'OW', u'V', u'ER', u'P', u'R', u'AH', u'D', u'UW', u'S', u'T'],
#   [u'overproduced']),
#  ([u'IY', u'AH'], [u'ia']),
#  ([u'D', u'EY', u'M', u'ER'], [u'damer']),
#  ([u'V', u'AY', u'AH', u'L', u'IH', u'T'], [u'violet']),
#  ([u'D', u'AY', u'AH', u'L', u'Z'], [u'dials', u"dial's"]),
#  ([u'OW', u'V', u'ER', u'P', u'R', u'AY', u'S', u'T'], [u'overpriced']),
#  ([u'K', u'ER', u'M', u'IH', u'T'], [u'kermit']),
#  ([u'F', u'IY', u'L', u'D', u'K', u'R', u'EH', u'S', u'T'], [u'fieldcrest']),
#  ([u'N', u'AY', u'N', u'ER'], [u'niner']),
#  ([u'AA', u'R', u'K', u'AH', u'V', u'IH', u'S', u'T'], [u'archivist']),
#  ([u'EY', u'L', u'AA', u'R'], [u'alar']),
#  ([u'T', u'R', u'AE', u'N', u'S', u'EH', u'N', u'D'], [u'transcend']),
#  ([u'K', u'ER', u'AA', u'L', u'OW'], [u'carollo']),
#  ([u'P', u'AO', u'R', u'T', u'EH', u'L', u'IY'], [u'portelli']),
#  ([u'K', u'L', u'AH', u'CH'], [u'clutch']),
#  ([u'HH', u'OW', u'M', u'OW'], [u'homo']),
#  ([u'D', u'AY', u'AH', u'L', u'D'], [u'dialed']),
#  ([u'IH', u'D', u'IY', u'OW', u'P', u'AE', u'TH'], [u'idiopath']),
#  ([u'R', u'OW', u'D', u'Z'],
#   [u'rhoads',
#    u'rhoades',
#    u"road's",
#    u'roads',
#    u'rhodes',
#    u'roades',
#    u'rodes']),
#  ([u'M', u'AH', u'K', u'R', u'AA', u'S', u'K', u'IY'], [u'mccroskey']),
#  ([u'B', u'EH', u'L', u'S', u'AH', u'N'], [u'belson']),
#  ([u'B', u'R', u'AA', u'NG', u'K', u'AY', u'T', u'AH', u'S'], [u'bronchitis']),
#  ([u'K', u'AA', u'R', u'N', u'AH', u'L'],
#   [u'carnell', u'karnal', u'carneal', u'carnal']),
#  ([u'T', u'UW', u'M', u'ER'], [u'tumor', u'toomer']),
#  ([u'S', u'IY', u'EH', u'N', u'EH', u'N'], [u'cnn']),
#  ([u'P', u'AA', u'L', u'IY', u'OW'], [u'pollio']),
#  ([u'SH', u'AE', u'N', u'S', u'EH', u'V'], [u'shansev']),
#  ([u'S', u'P', u'IH', u'D', u'AH', u'L'], [u'spidell', u'spidel']),
#  ([u'K', u'AO', u'R', u'S', u'OW'], [u'corso']),
#  ([u'P', u'R', u'UW', u'V', u'D'], [u'proved']),
#  ([u'L', u'AH', u'K', u'R', u'AO', u'S'],
#   [u'la-crosse', u'lacrosse', u'lacross']),
#  ([u'P', u'IH', u'N', u'AH', u'SH', u'EY'], [u'pinochet']),
#  ([u'K', u'AA', u'S', u'T', u'AO', u'F'], [u'kostoff']),
#  ([u'W', u'AO', u'L', u'S', u'EH', u'N', u'D'], [u'wallsend']),
#  ([u'K', u'L', u'EH', u'P', u'F', u'ER'], [u'klepfer']),
#  ([u'P', u'R', u'UW', u'V', u'Z'], [u'proves']),
#  ([u'S', u'T', u'EH', u'G', u'M', u'AH', u'N'], [u'stegmann', u'stegman']),
#  ([u'N', u'AE', u'SH', u'AH', u'N', u'AH', u'L'], [u'national']),
#  ([u'P', u'R', u'AE', u'N', u'S'], [u'prance']),
#  ([u'AH', u'P', u'OW', u'L', u'S', u'T', u'ER'], [u'upholster']),
#  ([u'R', u'AA', u'T', u'S', u'AA', u'N', u'OW'], [u'razzano']),
#  ([u'OW', u'B', u'EY', u'IH', u'NG'], [u'obeying']),
#  ([u'G', u'Y', u'UW', u'HH', u'AA', u'M', u'AH'], [u'gyuhama']),
#  ([u'AH', u'D', u'AO', u'R'], [u'adore']),
#  ([u'N', u'EH', u'T', u'V', u'Y', u'UW'], [u'netview']),
#  ([u'K', u'L', u'AE', u'S', u'R', u'UW', u'M', u'Z'], [u'classrooms']),
#  ([u'D', u'AW', u'B', u'IH', u'K'], [u'doubek']),
#  ([u'M', u'IY', u'T', u'ER', u'Z'], [u'meters']),
#  ([u'W', u'UH', u'D', u'AH', u'N'], [u'wooden']),
#  ([u'W', u'UH', u'D', u'AH', u'L'], [u'woodle', u'wooddell', u'woodell']),
#  ([u'D',
#    u'IY',
#    u'HH',
#    u'Y',
#    u'UW',
#    u'M',
#    u'IH',
#    u'D',
#    u'AH',
#    u'F',
#    u'AY',
#    u'D'],
#   [u'dehumidified']),
#  ([u'D',
#    u'IY',
#    u'HH',
#    u'Y',
#    u'UW',
#    u'M',
#    u'IH',
#    u'D',
#    u'AH',
#    u'F',
#    u'AY',
#    u'Z'],
#   [u'dehumidifies']),
#  ([u'G', u'AO', u'R', u'T', u'ER'], [u'gorter']),
#  ([u'W', u'UH', u'D', u'AH', u'V'], [u"would've"]),
#  ([u'D', u'AW', u'B', u'IH', u'T'], [u'doubet']),
#  ([u'M', u'EH', u'K', u'L', u'ER'], [u'meckler', u'mechler']),
#  ([u'W', u'OY', u'N', u'ER', u'AW', u'S', u'K', u'IY'], [u'wojnarowski']),
#  ([u'IH', u'N', u'T', u'AY', u'S', u'T'], [u'enticed']),
#  ([u'AE', u'K', u'S', u'AA', u'N', u'Z'], [u'axons']),
#  ([u'K', u'AE', u'S', u'IH', u'M', u'IY', u'R'], [u'casimir']),
#  ([u'B', u'L', u'EY', u'N', u'IY'], [u'blayney', u'blaney']),
#  ([u'S', u'UW', u'DH', u'Z'], [u'soothes']),
#  ([u'HH', u'AH', u'S', u'K'], [u'husk']),
#  ([u'P', u'UW', u'CH', u'IY', u'N', u'EH', u'L', u'IY'], [u'puccinelli']),
#  ([u'P', u'IH', u'N', u'OW'], [u'pinnow', u'pineau']),
#  ([u'AY', u'D', u'IY', u'L', u'IH', u'S', u'T'], [u'idealist']),
#  ([u'R', u'AH', u'N', u'AO', u'F'], [u'runoff']),
#  ([u'IH', u'M', u'AH', u'L', u'SH', u'AH', u'N'], [u'emulsion']),
#  ([u'R', u'AH', u'S', u'IY'], [u'russey']),
#  ([u'HH', u'AH', u'S', u'T'], [u'hust']),
#  ([u'S', u'UW', u'DH', u'D'], [u'soothed']),
#  ([u'D', u'AE', u'K', u'IH', u'S'], [u'dacus']),
#  ([u'R', u'IY', u'ER', u'EH', u'S', u'T'], [u'rearrest']),
#  ([u'TH', u'AA', u'M', u'S', u'AH', u'N'], [u'thomsen']),
#  ([u'P', u'EY', u'EH', u'T'], [u'payette']),
#  ([u'R', u'EH', u'P', u'L', u'IH', u'K', u'AH'], [u'replica']),
#  ([u'K', u'AA', u'M', u'AH', u'N', u'AE', u'L', u'AH', u'T', u'IY'],
#   [u'commonality']),
#  ([u'F', u'EY', u'N', u'ER'], [u'feighner']),
#  ([u'K', u'AA', u'M', u'P', u'L', u'EY', u'N', u'ER', u'Z'], [u'complainers']),
#  ([u'S', u'P', u'IY', u'K', u'ER', u'Z'], [u"speaker's", u'speakers']),
#  ([u'M', u'EY', u'L', u'S', u'T', u'R', u'AH', u'M'], [u'maelstrom']),
#  ([u'D', u'IH', u'S', u'T', u'R', u'OY', u'ER', u'Z'], [u'destroyers']),
#  ([u'G', u'AY', u'AA', u'N', u'AH'], [u'guyana']),
#  ([u'G', u'R', u'AE', u'B', u'AH', u'N'], [u'graben']),
#  ([u'G', u'R', u'AE', u'B', u'AH', u'L'], [u'grabel']),
#  ([u'P', u'AE', u'N', u'F', u'IH', u'L', u'AH'], [u'panphila']),
#  ([u'K', u'L', u'IH', u'T', u'S'], [u'klitz']),
#  ([u'T', u'AO', u'R', u'CH', u'ER', u'ER', u'Z'], [u'torturers']),
#  ([u'W', u'IH', u'L', u'W', u'ER', u'TH'], [u'willwerth']),
#  ([u'AH', u'B', u'S', u'T', u'EH', u'N', u'CH', u'AH', u'N', u'Z'],
#   [u'abstentions']),
#  ([u'T', u'IY', u'T', u'ER'], [u'teeter', u'teter', u'teater']),
#  ([u'HH', u'AE', u'M', u'AH', u'K', u'ER'], [u'hamacher']),
#  ([u'P', u'ER', u'S', u'IY', u'AH', u'S'], [u'perseus']),
#  ([u'B', u'AH', u'D', u'K', u'IY'], [u'budke']),
#  ([u'M', u'EH', u'R', u'IY'], [u'marry', u'merry', u'mary', u'merrie']),
#  ([u'D', u'IH', u'S', u'T', u'AH', u'N', u'S', u'IH', u'NG'], [u'distancing']),
#  ([u'Y', u'UW', u'EH', u'S', u'EH', u'R', u'Z'], [u"usair's"]),
#  ([u'S', u'AH', u'S', u'P', u'EH', u'N', u'D'], [u'suspend']),
#  ([u'P', u'R', u'AE', u'NG', u'K', u'S', u'T', u'ER', u'Z'], [u'pranksters']),
#  ([u'IH', u'N', u'AE', u'D', u'AH', u'K', u'W', u'AH', u'T', u'L', u'IY'],
#   [u'inadequately']),
#  ([u'Y', u'OW', u'D', u'AH', u'L'], [u'yodel']),
#  ([u'S', u'AH', u'S', u'P', u'EH', u'N', u'S'], [u'suspense']),
#  ([u'R',
#    u'EH',
#    u'G',
#    u'Y',
#    u'AH',
#    u'L',
#    u'EY',
#    u'T',
#    u'IH',
#    u'NG',
#    u'L',
#    u'IY'],
#   [u'regulatingly']),
#  ([u'CH', u'AY', u'D'], [u'chide']),
#  ([u'EY',
#    u'F',
#    u'AO',
#    u'R',
#    u'T',
#    u'UW',
#    u'W',
#    u'AH',
#    u'N',
#    u'T',
#    u'UW',
#    u'EY',
#    u'T'],
#   [u'a42128']),
#  ([u'W', u'AY', u'D', u'AH', u'N', u'Z'], [u'widens']),
#  ([u'M', u'IH', u'N', u'ER', u'D'], [u'minerd']),
#  ([u'AO', u'R', u'B', u'AH', u'T', u'ER'], [u'orbiter']),
#  ([u'AH', u'N', u'D', u'UW'], [u'undue', u'undo']),
#  ([u'AE', u'K', u'R', u'AH', u'M', u'OW', u'N', u'IY', u'AH', u'S'],
#   [u'acrimonious']),
#  ([u'G', u'R', u'AE', u'F', u'IH', u'K', u'S'], [u"graphics'", u'graphics']),
#  ([u'S', u'AH', u'L', u'EH', u'B', u'Z'], [u'celebs']),
#  ([u'T', u'R', u'AY', u'F', u'EH', u'K', u'T', u'AH'], [u'trifecta']),
#  ([u'IY',
#    u'V',
#    u'AE',
#    u'N',
#    u'JH',
#    u'EH',
#    u'L',
#    u'IH',
#    u'K',
#    u'AH',
#    u'L',
#    u'Z'],
#   [u'evangelicals']),
#  ([u'S', u'T', u'UW', u'D', u'IY', u'AH', u'S'], [u'studious']),
#  ([u'M', u'IH', u'M', u'Z'], [u'mimbs', u'mims', u'mimms']),
#  ([u'K',
#    u'AA',
#    u'N',
#    u'D',
#    u'AH',
#    u'M',
#    u'IH',
#    u'N',
#    u'IY',
#    u'AH',
#    u'M',
#    u'Z'],
#   [u'condominiums']),
#  ([u'HH', u'AA', u'JH', u'AH', u'N', u'Z'], [u'hodgens']),
#  ([u'D', u'OY', u'AA', u'L'], [u'doyal']),
#  ([u'M', u'IH', u'L', u'W', u'ER', u'D'], [u'millward', u'milward']),
#  ([u'M', u'AA', u'R', u'G', u'R', u'EH', u'T'], [u'margret']),
#  ([u'S', u'T', u'UW', u'D'], [u'stewed', u'stude']),
#  ([u'AA', u'S', u'T', u'ER'], [u'oster']),
#  ([u'K', u'L', u'AA', u'N', u'T', u'S'], [u'klontz', u'clontz', u'clonts']),
#  ([u'AH', u'W', u'AO', u'R', u'D', u'IH', u'NG'], [u'awarding']),
#  ([u'UW', u'Z', u'D'], [u'oozed']),
#  ([u'D', u'AH', u'NG', u'K', u'IH', u'N'], [u"dunkin'", u'dunkin']),
#  ([u'R', u'IH', u'D', u'IH', u'K', u'Y', u'AH', u'L', u'AH', u'S'],
#   [u'ridiculous']),
#  ([u'R', u'AH', u'B', u'ER', u'M', u'EY', u'D'], [u'rubbermaid']),
#  ([u'T', u'AE', u'M', u'P', u'AA', u'N'], [u'tampon']),
#  ([u'EH', u'N', u'T', u'R', u'EH', u'N', u'CH'], [u'entrench']),
#  ([u'L', u'AA', u'R', u'IY', u'N', u'IY'], [u'larine']),
#  ([u'K', u'AE', u'M', u'P', u'AH', u'S', u'AH', u'Z'], [u'campuses']),
#  ([u'JH', u'AA', u'N', u'Z', u'T', u'AW', u'N', u'Z'], [u"johnstown's"]),
#  ([u'IH', u'K', u'S', u'P', u'EH', u'L', u'D'], [u'expelled']),
#  ([u'S', u'P', u'EH', u'SH', u'AH', u'L', u'IY'], [u'specially']),
#  ([u'R', u'EH', u'Z', u'IH', u'D', u'AH', u'N', u'S'], [u'residence']),
#  ([u'R', u'EH', u'Z', u'IH', u'D', u'AH', u'N', u'T'], [u'resident']),
#  ([u'M', u'AA', u'N', u'T', u'UW', u'TH'], [u'montooth']),
#  ([u'B', u'AY', u'R', u'Z'], [u'bires']),
#  ([u'M', u'AO', u'L', u'K', u'AH', u'V', u'IH', u'CH'], [u'malkovich']),
#  ([u'M',
#    u'AH',
#    u'L',
#    u'T',
#    u'IY',
#    u'K',
#    u'AH',
#    u'L',
#    u'CH',
#    u'ER',
#    u'AH',
#    u'L',
#    u'IH',
#    u'Z',
#    u'AH',
#    u'M'],
#   [u'multiculturalism']),
#  ([u'L', u'IY', u'G', u'AH', u'L', u'IH', u'Z', u'AH', u'M'], [u'legalism']),
#  ([u'V', u'AH', u'G', u'IH', u'S', u'N', u'AE', u'K', u'S'], [u'vegisnax']),
#  ([u'IH', u'N', u'ER', u'T'], [u'inert']),
#  ([u'B', u'R', u'EH', u'S', u'T', u'ER'], [u'brester']),
#  ([u'B', u'AA', u'R', u'B', u'AE', u'R', u'AH', u'T', u'IY'], [u'barbarity']),
#  ([u'N', u'EY', u'T', u'IH', u'V'], [u'native']),
#  ([u'B', u'AE', u'K', u'S', u'IY', u'T', u'S'], [u'backseats']),
#  ([u'R', u'IY', u'K', u'L', u'EY', u'M'], [u'reclaim']),
#  ([u'AA', u'P', u'D', u'AA', u'L'], [u'opdahl']),
#  ([u'AO', u'R', u'IY', u'OW'], [u'oreo']),
#  ([u'S', u'AE', u'D', u'AH', u'L'], [u'saddle']),
#  ([u'S', u'AE', u'D', u'AH', u'N'], [u'sadden']),
#  ([u'L', u'IY', u'B', u'ER'], [u'leiber', u'libor', u'leber', u'lieber']),
#  ([u'HH', u'AE', u'M', u'ER', u'S', u'AH', u'N'], [u'hammerson']),
#  ([u'W', u'IH', u'T', u'ER', u'Z'], [u"witter's", u'witters']),
#  ([u'F', u'L', u'EH', u'M', u'IH', u'S', u'T', u'ER'], [u'flemister']),
#  ([u'AE', u'D', u'AH', u'B', u'AH', u'L'], [u'adabelle']),
#  ([u'M', u'OW', u'T', u'AH', u'V', u'EY', u'T', u'ER'], [u'motivator']),
#  ([u'IY', u'G', u'AH', u'L', u'T', u'AH', u'N'], [u'eagleton']),
#  ([u'K', u'AH', u'M', u'ER', u'SH', u'AH', u'L', u'IH', u'Z', u'AH', u'M'],
#   [u'commercialism']),
#  ([u'G', u'AE', u'L', u'AH', u'K', u'S', u'IY', u'Z'],
#   [u"galaxy's", u'galaxies']),
#  ([u'P', u'IY', u'N', u'AH'], [u'pina']),
#  ([u'K', u'AH', u'T'], [u'cut', u'kut']),
#  ([u'D', u'IY', u'L', u'M', u'AO', u'R'], [u'dilmore']),
#   [u'sympathizing']),
#  ([u'EH', u'K', u'S', u'T', u'IY', u'N'], [u'eckstein']),
#  ([u'AH', u'P', u'CH', u'ER', u'CH'], [u'upchurch']),
#  ([u'P', u'EH', u'R', u'AH', u'T', u'S'], [u'parrots']),
#  ([u'TH', u'IY', u'B', u'Z'], [u'thebes']),
#  ([u'HH', u'EH', u'D', u'Z'], [u'heads', u"head's"]),
#  ([u'R', u'IY', u'L', u'EY', u'SH', u'AH', u'N', u'SH', u'IH', u'P', u'S'],
#   [u'relationships']),
#  ([u'L', u'IY', u'TH', u'AE', u'L', u'AH', u'T', u'IY'], [u'lethality']),
#  ([u'S', u'AA', u'HH', u'AH'], [u'saha']),
#  ([u'K', u'R', u'EY', u'K', u'ER'], [u'kraker', u'craker']),
#  ([u'S', u'P', u'AY', u'N', u'AH', u'L'], [u'spinal']),
#  ([u'HH', u'UW'], [u'who', u'hu', u'hoo', u'hou', u'houx']),
#  ([u'F', u'IH', u'N', u'AE', u'N', u'S', u'IH', u'Z'], [u'finances']),
#  ([u'K', u'L', u'EH', u'R', u'AH', u'F', u'AY', u'IH', u'NG'],
#   [u'clarifying']),
#  ([u'M', u'IH', u'L', u'IH', u'T', u'ER', u'IH', u'S', u'T', u'IH', u'K'],
#   [u'militaristic']),
#  ([u'EH', u'L', u'V', u'IH', u'NG'], [u'elving']),
#  ([u'B', u'ER', u'AA', u'M', u'IH', u'T', u'ER', u'Z'], [u'barometers']),
#  ([u'D', u'IH', u'R', u'AY', u'T', u'ER'], [u'deruyter']),
#  ([u'HH', u'EH', u'L', u'S', u'ER'], [u'helser']),
#  ([u'B', u'OW', u'L', u'SH', u'AH', u'V', u'IH', u'K'], [u'bolshevik']),
#  ([u'K', u'AO', u'R', u'K', u'AH', u'N'], [u'corken']),
#  ([u'S', u'UW', u'B', u'ER'], [u'suber']),
#  ([u'F', u'IH', u'R', u'S', u'AH', u'S', u'T'], [u'fiercest']),
#  ([u'L', u'AH', u'S', u'IH', u'V', u'IY', u'AH', u'S'], [u'lascivious']),
#  ([u'M', u'AA', u'T', u'AH'], [u'mata']),
#  ([u'S', u'W', u'AA', u'DH', u'D'], [u'swathed']),
#  ([u'JH', u'AE', u'F', u'K', u'OW'], [u'jafco']),
#  ([u'T', u'AH', u'L', u'IH', u'S'], [u'tullis']),
#  ([u'IH',
#    u'K',
#    u'S',
#    u'P',
#    u'R',
#    u'EH',
#    u'SH',
#    u'AH',
#    u'N',
#    u'IH',
#    u'S',
#    u'T',
#    u'IH',
#    u'K'],
#   [u'expressionistic']),
#  ([u'K', u'AA', u'N', u'R', u'AH', u'TH'], [u'conrath', u'konrath']),
#  ([u'V', u'EH', u'N', u'T', u'R', u'IH', u'K', u'Y', u'UW', u'L', u'ER'],
#   [u'ventricular']),
#  ([u'AW', u'T', u'F', u'AA', u'K', u'S', u'IH', u'Z'], [u'outfoxes']),
#  ([u'K', u'OW', u'L', u'IY', u'ER'], [u'colyer', u'colier']),
#  ([u'K', u'EY', u'K', u'EY', u'K', u'EY'], [u'kkk']),
#  ([u'P',
#    u'Y',
#    u'UH',
#    u'R',
#    u'AH',
#    u'T',
#    u'AE',
#    u'N',
#    u'IH',
#    u'K',
#    u'AH',
#    u'L'],
#   [u'puritanical']),
#  ([u'N', u'AH', u'G', u'L', u'EH', u'K', u'T', u'AH', u'D'], [u'neglected']),
#  ([u'F', u'IH', u'G', u'Z'], [u'figs', u'figgs']),
#  ([u'IH', u'L', u'EH', u'K', u'T', u'IH', u'V'], [u'elective']),
#  ([u'K', u'AA', u'N', u'S', u'T', u'AH', u'T', u'UW', u'SH', u'AH', u'N'],
#   [u'constitution']),
#  ([u'F', u'UW', u'JH', u'IY', u'IY'], [u'fujii']),
#  ([u'R', u'AY', u'F', u'AH', u'L'], [u'rifle', u'reifel']),
#  ([u'HH', u'EH', u'D', u'M', u'AE', u'S', u'T', u'ER', u'Z'],
#   [u'headmasters']),
#  ([u'S', u'K', u'AE', u'L', u'F', u'AA', u'R', u'OW'], [u'scalfaro']),
#  ([u'D',
#    u'AH',
#    u'L',
#    u'EH',
#    u'K',
#    u'T',
#    u'R',
#    u'IH',
#    u'S',
#    u'AH',
#    u'T',
#    u'EY'],
#   [u"d'electricite"]),
#  ([u'D', u'IH', u'S', u'P', u'ER', u'S', u'IH', u'NG'], [u'dispersing']),
#  ([u'G', u'OW', u'M', u'AH'], [u'goma']),
#  ([u'R', u'IY', u'S', u'ER', u'CH'], [u'research']),
#  ([u'S', u'ER', u'T', u'IH', u'F', u'IH', u'K', u'AH', u'T'],
#   [u'certificate']),
#  ([u'W', u'EH', u'T', u'S', u'T', u'IY', u'N'], [u'whetstine', u'wetstein']),
#  ([u'IH', u'N', u'EH', u'B', u'R', u'IY', u'EY', u'T', u'S'], [u'inebriates']),
#  ([u'SH', u'EH', u'M', u'AH', u'L'], [u'schemel', u'schemmel']),
#  ([u'B', u'AH', u'K', u'IH', u'NG', u'HH', u'AE', u'M'], [u'buckingham']),
#  ([u'B', u'AE', u'T', u'AH', u'N', u'R', u'UW', u'JH'], [u'baton-rouge']),
#  ([u'W', u'UH', u'D', u'K', u'AA', u'R', u'V', u'ER', u'Z'], [u'woodcarvers']),
#  ([u'CH', u'AE', u'T', u'AH', u'M'], [u'chatham']),
#  ([u'L', u'AH', u'M', u'ER', u'S', u'IY', u'ER'], [u'lemercier']),
#  ([u'W', u'IY', u'ER', u'Z'], [u'weers']),
#  ([u'D', u'EY', u'K', u'EH', u'R'], [u'daycare']),
#  ([u'M', u'IH', u'N', u'EH', u'R', u'OW'], [u'minero']),
#  ([u'D', u'AO', u'R', u'AH', u'L', u'AY', u'N'], [u'doralynne']),
#  ([u'S', u'T', u'R', u'AY', u'N'], [u'strine']),
#  ([u'S', u'T', u'R', u'AY', u'K'], [u'streich', u'strike']),
#  ([u'AO', u'R', u'K', u'IH', u'S', u'T', u'R', u'EY', u'T'], [u'orchestrate']),
#  ([u'G', u'OW', u'L', u'D'], [u'golde', u'gold']),
#  ([u'HH', u'EH', u'L', u'M', u'AH', u'T', u'S'], [u'helmets']),
#  ([u'K', u'EY', u'S', u'IY'], [u'casey', u'caissie']),
#  ([u'AH', u'L', u'AY', u'V'], [u'alive']),
#  ([u'P', u'R', u'EH', u'Z', u'AH', u'D', u'AH', u'N', u'S', u'IY'],
#   [u'presidency']),
#  ([u'AH', u'L', u'AY', u'T'], [u'alight']),
#  ([u'B', u'R', u'AE', u'CH', u'ER'], [u'bratcher']),
#  ([u'F', u'AA', u'R', u'AH', u'W', u'EY'], [u'faraway']),
#  ([u'L', u'OW', u'G', u'OW', u'Z'], [u'logos']),
#  ([u'P',
#    u'EH',
#    u'N',
#    u'S',
#    u'IH',
#    u'L',
#    u'V',
#    u'EY',
#    u'N',
#    u'IY',
#    u'AH',
#    u'N'],
#   [u'pennsylvanian']),
#  ([u'B', u'AE', u'N', u'IH', u'T'], [u'banet']),
#  ([u'D', u'IH', u'S', u'T', u'ER', u'B'], [u'disturb']),
#  ([u'B', u'AE', u'L', u'B', u'R', u'IH', u'G', u'AH', u'N', u'Z'],
#   [u'balbriggans']),
#  ([u'F', u'IH', u'F', u'T', u'IY'], [u'fiftee', u'fifty']),
#  ([u'JH', u'AH', u'N', u'JH', u'IY'], [u'junji']),
#  ([u'AH', u'N', u'D', u'UW', u'L', u'IY'], [u'unduly']),
#  ([u'F', u'R', u'AH', u'M', u'P'], [u'frump']),
#  ([u'F', u'IH', u'N', u'L', u'IY', u'Z'], [u"finley's"]),
#  ([u'Y', u'AH', u'B', u'IY', u'N', u'AH'], [u'jobyna']),
#  ([u'AE', u'L', u'M', u'G', u'R', u'EH', u'N'], [u'almgren']),
#  ([u'HH', u'ER', u'AA', u'R', u'IY'], [u'harare']),
#  ([u'IH', u'M', u'AO', u'R', u'T', u'AH', u'L', u'AY', u'Z', u'IH', u'Z'],
#   [u'immortalizes']),
#  ([u'Z', u'AH', u'L', u'EY'], [u'zalay']),
#  ([u'R', u'AA', u'K', u'W', u'UH', u'D'], [u'rockwood']),
#  ([u'N', u'AA', u'K', u'T'], [u'knocked']),
#  ([u'N', u'AA', u'K', u'S'], [u'knocks', u'knox']),
#  ([u'P', u'EY', u'P', u'ER', u'L', u'AH', u'S'], [u'paperless']),
#  ([u'D', u'EH', u'K', u'R', u'IH', u'S', u'T', u'AA', u'F', u'ER'],
#   [u'dechristopher']),
#  ([u'D', u'IH', u'S', u'K', u'OW', u'T', u'EH', u'K'], [u'discotheque']),
#  ([u'R', u'AH', u'B', u'AH', u'T', u'AA', u'M'], [u'rubottom']),
#  ([u'AO', u'T', u'AA', u'K', u'R', u'AH', u'S', u'IY'], [u'autocracy']),
#  ([u'Y', u'UW', u'N', u'Y', u'AH', u'N', u'AH', u'S', u'T'], [u'unionist']),
#  ([u'P', u'R', u'AA', u'S', u'P', u'EH', u'K', u'T'],
#   [u'prospect', u'prospekt']),
#  ([u'G', u'R', u'EY', u'Z', u'ER'], [u'grazer', u'graeser', u'graser']),
#  ([u'AA', u'R', u'M', u'W', u'UH', u'D'], [u'armwood']),
#  ([u'S', u'AH', u'B', u'M', u'ER', u'S', u'T'], [u'submersed']),
#  ([u'R', u'IH', u'V', u'ER', u'D', u'EY', u'L'], [u'riverdale']),
#  ([u'S', u'EY', u'L', u'AH', u'B', u'AH', u'L'], [u'saleable', u'salable']),
#  ([u'D', u'AA', u'N', u'Z'], [u'dons', u"don's", u'donze']),
#  ([u'N', u'ER', u'CH', u'ER'], [u'nurture']),
#  ([u'G', u'R', u'EY', u'B', u'IY', u'R', u'D'], [u'graybeard']),
#  ([u'S', u'K', u'IY', u'OW', u'T', u'OW'], [u'scioto']),
#  ([u'AE', u'S', u'IH', u'V', u'AA', u'L'], [u'accival']),
#  ([u'AA', u'L', u'B', u'AA', u'N', u'EY', u'Z', u'IY'], [u'albanese']),
#  ([u'N', u'AO', u'R', u'M', u'AH', u'L', u'AY', u'Z', u'IH', u'Z'],
#   [u'normalizes']),
#  ([u'D',
#    u'IH',
#    u'S',
#    u'IH',
#    u'N',
#    u'T',
#    u'AH',
#    u'G',
#    u'R',
#    u'EY',
#    u'SH',
#    u'AH',
#    u'N'],
#   [u'disintegration']),
#  ([u'T',
#    u'R',
#    u'AE',
#    u'N',
#    u'S',
#    u'P',
#    u'EH',
#    u'R',
#    u'AH',
#    u'N',
#    u'S',
#    u'IY',
#    u'Z'],
#   [u'transparencies']),
#  ([u'EH', u'K', u'S', u'AH', u'M', u'AH'], [u'eczema']),
#  ([u'V', u'EH', u'N', u'D', u'EH', u'T', u'AH', u'Z'], [u'vendettas']),
#  ([u'S', u'T', u'AA', u'F', u'ER'], [u'stopher']),
#  ([u'D', u'AA', u'N', u'D'], [u'donde', u'donned']),
#  ([u'S', u'EH', u'N', u'T', u'AH', u'N', u'EH', u'R', u'IY'], [u'centenary']),
#  ([u'S', u'T', u'AA', u'R', u'D', u'AH', u'M'], [u'stardom']),
#  ([u'JH', u'ER', u'M', u'AH', u'N', u'EY', u'T', u'IH', u'D'],
#   [u'germinated']),
#  ([u'W', u'IH', u'K', u'ER', u'N'], [u'wichern']),
#  ([u'T', u'S', u'UW', u'T', u'OW', u'M', u'UW'], [u'tsutomu']),
#  ([u'R', u'AY', u'L', u'AH', u'N', u'D'], [u'reiland']),
#  ([u'W', u'IH', u'K', u'ER', u'D'], [u'wickard']),
#  ([u'D', u'IH', u'K', u'T', u'EY', u'SH', u'AH', u'N'], [u'dictation']),
#  ([u'K', u'AH', u'L', u'IH', u'F', u'ER'], [u'cullipher', u'cullifer']),
#  ([u'S', u'T', u'IY', u'M', u'R', u'OW', u'L', u'ER'], [u'steamroller']),
#  ([u'B', u'R', u'UW', u'T', u'IH', u'SH'], [u'brutish']),
#  ([u'R', u'IY', u'L', u'EY'], [u'relay']),
#  ([u'D', u'AY', u'V', u'ER', u'T'], [u'divert']),
#  ([u'W', u'IH', u'K', u'ER', u'T'], [u'wickert']),
#  ([u'IH', u'K', u'S', u'P', u'AY', u'R', u'IH', u'NG'], [u'expiring']),
#  ([u'D', u'R', u'AH', u'G', u'AH', u'S', u'T', u'S'],
#   [u'druggists', u"druggist's"]),
#  ([u'HH', u'AE', u'V', u'IH', u'NG', u'T', u'AH', u'N', u'Z'],
#   [u"havington's"]),
#  ([u'F', u'AE', u'L', u'K', u'AH', u'N', u'R', u'IY'], [u'falconry']),
#  ([u'AE', u'N', u'T', u'AH', u'N', u'IY'], [u'antony']),
#  ([u'IH', u'N', u'F', u'OW', u'M', u'ER', u'SH', u'AH', u'L'],
#   [u'infomercial']),
#  ([u'T', u'IY', u'B', u'OW', u'N'], [u't-bone']),
#  ([u'S', u'T', u'EY', u'V', u'L', u'IY'], [u'stavely']),
#  ([u'S', u'AY', u'M', u'AH', u'N'], [u'simon']),
#  ([u'R', u'OW', u'D', u'B', u'L', u'AA', u'K', u'S'], [u'roadblocks']),
#  ([u'B', u'R', u'AE', u'NG', u'K', u'S'], [u'branks', u"brank's"]),
#  ([u'IH', u'F', u'AH', u'JH', u'AH', u'N', u'AY', u'AH'], [u'iphegenia']),
#  ([u'SH', u'IH', u'P', u'M', u'AH', u'N', u'T'], [u'shipment']),
#  ([u'L', u'IY', u'P', u'UW', u'M', u'AH'], [u'lipuma']),
#  ([u'IH',
#    u'D',
#    u'IY',
#    u'OW',
#    u'S',
#    u'IH',
#    u'N',
#    u'K',
#    u'R',
#    u'AH',
#    u'S',
#    u'IY',
#    u'Z'],
#   [u'idiosyncrasies']),
#  ([u'F', u'L', u'AY', u'T', u'L', u'AH', u'S'], [u'flightless']),
#  ([u'B', u'AE', u'G', u'IH', u'NG'], [u'bagging']),
#  ([u'B', u'EH', u'N', u'HH', u'AH', u'M'], [u'benham']),
#  ([u'R', u'AH', u'D', u'AO', u'SH'], [u'radosh']),
#  ([u'HH', u'IY', u'L', u'IY', u'OW', u'N', u'EH', u'T', u'IH', u'K', u'S'],
#   [u'helionetics']),
#  ([u'S', u'AE', u'N', u'AH'], [u'sanna']),
#  ([u'Z', u'IY', u'AA', u'L', u'IY'], [u'zeoli']),
#  ([u'P', u'OW', u'P', u'AH'], [u'popa']),
#  ([u'W', u'ER', u'DH', u'IY', u'Z'], [u'worthies']),
#  ([u'AE', u'N', u'AH', u'D', u'AA', u'R', u'K', u'OW', u'Z'], [u"anadarko's"]),
#  ([u'AA', u'P', u'AH', u'L'], [u'oppel']),
#  ([u'K', u'AA', u'R', u'T', u'ER'], [u'karter', u'carter']),
#  ([u'K', u'ER', u'T', u'IH', u'N', u'B', u'AA', u'K'], [u'kurtenbach']),
#  ([u'S', u'T', u'AE', u'N', u'D', u'IH', u'SH'], [u'standish']),
#  ([u'S', u'W', u'IH', u'CH', u'B', u'L', u'EY', u'D', u'Z'],
#   [u'switchblades']),
#  ([u'S', u'K', u'AA', u'R', u'F', u'S'], [u'scarfs']),
#  ([u'P', u'AA', u'R', u'T', u'IH', u'S', u'IH', u'P', u'AH', u'L', u'Z'],
#   [u'participles']),
#  ([u'HH', u'AE', u'T', u'IH', u'M'], [u'hatem']),
#  ([u'D', u'AA', u'N', u'Z', u'B', u'AA', u'K'], [u'donsbach']),
#  ([u'S', u'K', u'AY', u'R', u'AY', u'T', u'ER', u'Z'], [u'skywriters']),
#  ([u'D', u'AE', u'L', u'AY', u'D', u'AH', u'N'], [u'daleiden']),
#  ([u'T', u'R', u'EY', u'L', u'ER'], [u'trailer', u'traylor']),
#  ([u'D', u'AA', u'K', u'AH', u'T'], [u'docket']),
#  ([u'L', u'AE', u'N', u'D', u'Z', u'M', u'AH', u'N'], [u'landsman']),
#  ([u'N', u'AA', u'V', u'AA', u'R'], [u'navar', u'navarre']),
#  ([u'W', u'AA', u'CH', u'D', u'AO', u'G', u'Z'], [u'watchdogs']),
#  ([u'K', u'AH', u'B', u'R', u'IY', u'N', u'IY', u'Z'], [u"cabrini's"]),
#  ([u'T', u'OW', u'M', u'EY', u'N'], [u'ptomaine']),
#  ([u'S', u'P', u'IH', u'R', u'M', u'AH', u'N'], [u'spearman']),
#  ([u'D', u'AA', u'K', u'AH', u'N'], [u'dokken', u'docken']),
#  ([u'HH', u'AE', u'N', u'K', u'AA', u'K', u'S'], [u"hancock's", u'hancox']),
#  ([u'IH', u'N', u'R', u'OW', u'D', u'Z'], [u'inroads']),
#  ([u'L', u'AH', u'K', u'IY', u'AH', u'S', u'T'], [u'luckiest']),
#  ([u'D',
#    u'EH',
#    u'M',
#    u'AH',
#    u'K',
#    u'R',
#    u'AE',
#    u'T',
#    u'IH',
#    u'K',
#    u'L',
#    u'IY'],
#   [u'democratically']),
#  ([u'K', u'AE', u'R', u'AH', u'V', u'AE', u'N'], [u'caravan']),
#  ([u'IH',
#    u'N',
#    u'IH',
#    u'G',
#    u'Z',
#    u'AO',
#    u'S',
#    u'T',
#    u'AH',
#    u'B',
#    u'AH',
#    u'L'],
#   [u'inexhaustible']),
#  ([u'K', u'AE', u'N', u'AH', u'N', u'Z'],
#   [u"cannon's", u'cannons', u'canons', u"canon's"]),
#  ([u'F', u'EY', u'SH', u'AH', u'L', u'Z'], [u'facials']),
#  ([u'AE', u'L', u'IH', u'K', u'S', u'AA', u'N', u'D', u'ER'], [u'alexandre']),
#  ([u'AH', u'L', u'IY', u'R', u'IY', u'AH'], [u'aleria']),
#  ([u'HH', u'AH', u'B', u'N', u'ER'], [u'hubner']),
#  ([u'S', u'OW', u'P', u'K', u'OW'], [u'sopko']),
#  ([u'T', u'AH', u'M', u'B', u'AH', u'L', u'Z'], [u'tumbles']),
#  ([u'M', u'AA', u'S', u'OW', u'N', u'IY'], [u'massoni']),
#  ([u'K', u'OW', u'IH', u'N', u'S', u'AY', u'D', u'Z'], [u'coincides']),
#  ([u'T', u'EY', u'L', u'EH', u'Z'], [u'tellez']),
#  ([u'CH', u'IH', u'L', u'T', u'AH', u'N'], [u'chilton']),
#  ([u'HH', u'AE', u'L', u'AH', u'W', u'EH', u'L'], [u'hallowell']),
#  ([u'T', u'UW', u'F', u'OW', u'L', u'D'], [u'twofold']),
#  ([u'T', u'AH', u'M', u'B', u'AH', u'L', u'D'], [u'tumbled']),
#  ([u'K', u'AE', u'S', u'T', u'R', u'IH', u'JH', u'AA', u'N'], [u'castrejon']),
#  ([u'HH', u'OW', u'F', u'N', u'ER'], [u'hoeffner']),
#  ([u'D', u'AW', u'N', u'W', u'IH', u'N', u'D'], [u'downwind']),
#  ([u'G', u'IH', u'L', u'B', u'R', u'EH', u'TH'], [u'gilbreath']),
#  ([u'AO', u'TH', u'AH', u'N', u'T', u'IH', u'S', u'IH', u'T', u'IY'],
#   [u'authenticity']),
#  ([u'T', u'IH', u'N', u'IH', u'N'], [u'tinnin']),
#  ([u'L', u'AE', u'N', u'D', u'V', u'Y', u'UW', u'Z'], [u"landview's"]),
#  ([u'IY', u'K', u'W', u'AH', u'L', u'AY', u'Z'], [u'equalize']),
#  ([u'K', u'AA', u'L', u'IH', u'JH', u'IH', u'Z'],
#   [u"college's", u'colleges', u"colleges'"]),
#  ([u'AH', u'N', u'K', u'AH', u'N', u'S', u'ER', u'N'], [u'unconcern']),
#  ([u'P', u'IY', u'Z', u'IY'], [u'peasey']),
#  ([u'F', u'OY', u'B', u'AH', u'L'], [u'foible']),
#  ([u'P', u'AA', u'S', u'AH', u'M'], [u'possum']),
#  ([u'AO', u'T', u'OW', u'K', u'L', u'EY', u'V'], [u'autoclave']),
#  ([u'K', u'AH', u'P', u'IH', u'SH', u'K', u'IY'], [u'kopischke']),
#  ([u'R', u'EH', u'T', u'R', u'OW', u'S', u'EH', u'SH', u'AH', u'N'],
#   [u'retrocession']),
#  ([u'M', u'AA', u'N', u'T', u'ER', u'EY'], [u'monterey', u'monterrey']),
#  ([u'CH', u'AE', u'M', u'P', u'IY', u'AH', u'N', u'Z'],
#   [u'champions', u"champion's"]),
#  ([u'AH', u'M', u'B', u'AH', u'L'], [u'umble', u'umbel']),
#  ([u'B', u'AH', u'K', u'AO', u'L'], [u'bacall']),
#  ([u'M', u'EH', u'N', u'AH', u'N', u'AY', u'T'], [u'mennonite']),
#  ([u'D', u'EH', u'G', u'L', u'ER'], [u'degler']),
#  ([u'S', u'T', u'AA', u'S', u'IY', u'OW'], [u'stasio']),
#  ([u'EH',
#    u'K',
#    u'S',
#    u'T',
#    u'R',
#    u'AH',
#    u'S',
#    u'EH',
#    u'L',
#    u'Y',
#    u'AH',
#    u'L',
#    u'ER',
#    u'L',
#    u'IY'],
#   [u'extracellularly']),
#  ([u'M', u'EH', u'K', u'S', u'AH', u'K', u'OW'], [u'mexico']),
#  ([u'IH', u'NG', u'K', u'AH', u'Z'], [u'incas']),
#  ([u'N', u'IH', u'K', u'ER', u'AA', u'G', u'W', u'AH'], [u'nicaragua']),
#  ([u'EH', u'JH', u'AH', u'K', u'EY', u'SH', u'AH', u'N'], [u'education']),
#  ([u'M', u'UH', u'HH', u'AA', u'M', u'EH', u'D'], [u'muhamed', u'muhammed']),
#  ([u'L', u'ER', u'N', u'T'], [u'learnt']),
#  ([u'W', u'IH', u'N', u'D', u'IY'], [u'windy']),
#  ([u'HH', u'AE', u'N', u'D', u'L', u'ER', u'Z'], [u'handlers']),
#  ([u'K', u'R', u'AE', u'T', u'AH', u'K', u'V', u'AH', u'L'], [u'kratochvil']),
#  ([u'M', u'AA', u'N', u'T', u'P', u'IY', u'L', u'IY', u'ER'], [u'montpelier']),
#  ([u'B', u'UW', u'N', u'AH'], [u'buena']),
#  ([u'N', u'AY', u'N', u'EH', u'K', u'S'], [u'nynex']),
#  ([u'G', u'AE', u'NG', u'IH', u'NG'], [u'ganging']),
#  ([u'AE', u'P', u'IH', u'N', u'Z', u'AH', u'L', u'ER'], [u'appenzeller']),
#  ([u'P', u'EH', u'D', u'IY', u'G', u'OW'], [u'pedigo']),
#  ([u'HH', u'AE', u'Z', u'L', u'IH', u'T'], [u'hazlett']),
#  ([u'S', u'EH', u'M', u'L', u'ER'], [u'semmler', u'semler']),
#  ([u'P', u'R', u'OW', u'F', u'AE', u'N', u'AH', u'T', u'IY'], [u'profanity']),
#  ([u'T', u'R', u'EY', u'K', u'IY', u'AH', u'F', u'AY', u'T'],
#   [u'tracheophyte']),
# ...
#   [u'counterfeiters']),
#  ([u'AH', u'F', u'ER', u'M', u'IH', u'NG'], [u'affirming']),
#  ([u'P', u'IH', u'S', u'T', u'AH', u'L', u'Z'], [u'pistols']),
#  ([u'S', u'ER', u'IH', u'L', u'IH', u'K'], [u'cyrillic']),
#  ([u'R', u'AH', u'S', u'IH', u'N', u'S', u'K', u'IY'],
#   [u'rosinski', u'rosinsky']),
#  ([u'M', u'OW', u'L', u'IY', u'N', u'OW'], [u'molino']),
#  ([u'F', u'L', u'AE', u'M', u'B', u'OY', u'AH', u'N', u'T'], [u'flamboyant']),
#  ([u'Z', u'AE', u'M', u'Z', u'OW'], [u'zamzow']),
#  ([u'D', u'IH', u'S', u'AA', u'N', u'T', u'IH', u'S'], [u'disantis']),
#  ([u'M', u'AO', u'R', u'AO', u'N', u'S', u'IY'], [u'morency']),
#  ([u'G', u'AE', u'D', u'Z', u'B', u'IY'], [u'gadsby']),
#  ([u'R', u'EH', u'K', u'T', u'AE', u'NG', u'G', u'AH', u'L', u'Z'],
#   [u'rectangles']),
#  ([u'B', u'EH', u'T', u'IY', u'N', u'IY'], [u'bettini']),
#  ([u'F', u'AA', u'S', u'OW', u'Z'], [u"faso's"]),
#  ([u'S', u'N', u'AA', u'R', u'L', u'IH', u'NG'], [u'snarling']),
#  ([u'D', u'R', u'AH', u'Z', u'D', u'AO', u'F', u'S', u'K', u'IY'],
#   [u'drozdowski']),
#  ([u'M', u'EH', u'L', u'ER'], [u'melear', u'mehler', u'mellor', u'meller']),
#  ([u'G', u'AA', u'R', u'G', u'IH', u'S'], [u'gargis']),
#  ([u'SH', u'AH', u'P', u'EH', u'L'], [u'chapelle', u'chapell', u'chappelle']),
#  ([u'N', u'AH', u'Z', u'EH', u'R', u'IY', u'AH', u'N'], [u'nazarian']),
#  ([u'T', u'AA', u'M', u'AA', u'R', u'G', u'OW'], [u'tamargo']),
#  ([u'V', u'ER', u'S', u'AA', u'CH', u'EY', u'Z'], [u"versace's"]),
#  ([u'AA', u'N', u'ER', u'EH', u'R', u'IY', u'AH', u'M', u'Z'],
#   [u'honorariums']),
#  ([u'W', u'IH', u'D', u'AH', u'N'], [u'whiddon', u'whidden']),
#  ([u'R', u'OW', u'M', u'AA', u'N', u'IY'], [u'romani']),
#  ([u'W', u'IH', u'D', u'AH', u'L'], [u'widell', u'widdle']),
#  ([u'N', u'AA', u'N', u'AH', u'L', u'AY', u'N'], [u'nonalign']),
#  ([u'M', u'AH', u'K', u'L', u'AE', u'W', u'ER', u'N'], [u'mclawhorn']),
#  ([u'T', u'R', u'AA', u'P', u'IH', u'K', u'S'], [u'tropics']),
#  ([u'AH', u'N', u'D', u'IH', u'N', u'AY', u'AH', u'B', u'L', u'IY'],
#   [u'undeniably']),
#  ([u'D', u'IH', u'V', u'IY', u'V', u'OW'], [u'devivo']),
#  ([u'K', u'L', u'EH', u'V', u'IH', u'NG', u'ER'], [u'clevinger']),
#  ([u'EH', u'N', u'CH', u'AE', u'N', u'T', u'ER', u'Z'],
#   [u'enchanters', u"enchanter's"]),
#  ([u'AH', u'N', u'N', u'IY', u'D', u'IH', u'D'], [u'unneeded']),
#  ([u'B', u'IH', u'L', u'IH', u'T', u'AH', u'N'], [u'billiton']),
#  ([u'T', u'EH', u'L', u'AH', u'K', u'R', u'EH', u'D', u'IH', u'T'],
#   [u'telecredit']),
#  ([u'B', u'IH', u'L', u'IH', u'T', u'AH', u'L'], [u'belittle']),
#  ([u'S', u'P', u'UW', u'N', u'F', u'UH', u'L', u'Z'], [u'spoonfuls']),
#  ([u'F', u'AH', u'Z', u'IH', u'SH', u'AH', u'N'], [u'physician']),
#  ([u'B', u'AY', u'F', u'OW', u'K', u'AH', u'L', u'Z'], [u'bifocals']),
#  ([u'L', u'EY', u'G', u'ER', u'K', u'W', u'IH', u'S', u'T'], [u'lagerquist']),
#  ([u'AE', u'F', u'ER', u'M', u'EY', u'SH', u'AH', u'N', u'Z'],
#   [u'affirmations']),
#  ([u'F', u'L', u'AE', u'M', u'B', u'OY', u'AH', u'N', u'S'], [u'flamboyance']),
#  ([u'M',
#    u'AA',
#    u'N',
#    u'Y',
#    u'AH',
#    u'M',
#    u'EH',
#    u'N',
#    u'T',
#    u'AH',
#    u'L',
#    u'IY'],
#   [u'monumentally']),
#  ([u'L', u'AH', u'N', u'B', u'ER', u'G'], [u'lunberg']),
#  ([u'W', u'AH', u'HH', u'UW'], [u'wahoo']),
#  ([u'G', u'OW', u'L', u'D', u'S', u'T', u'AY', u'N'], [u'goldstein']),
#  ([u'M', u'EY', u'N', u'OW'], [u'meno', u'maino']),
#  ([u'IH', u'N', u'T', u'ER', u'T', u'R', u'AY', u'B', u'AH', u'L'],
#   [u'intertribal']),
#  ([u'AY', u'R', u'AH', u'N', u'IY', u'Z'], [u'ironies']),
#  ([u'N', u'AY', u'CH', u'ER', u'T'], [u'nightshirt']),
#  ([u'B', u'AA', u'Z', u'N', u'IY', u'AH', u'N', u'Z'],
#   [u'wyllie', u'willy', u'willie', u'willey', u'willi']),
#  ([u'AH', u'M', u'IY', u'L', u'IY', u'AH'], [u'emilia']),
#  ([u'SH', u'M', u'AE', u'L'], [u'schmal']),
#  ([u'R', u'OW', u'D', u'AA', u'L', u'F', u'OW'], [u'rodolfo']),
#  ([u'M', u'EH', u'SH', u'EH', u'D'], [u'mesched']),
#  ([u'AA', u'K', u'R', u'AH'], [u'ochra']),
#  ([u'V', u'AH', u'N', u'IH', u'L', u'IH', u'N'], [u'vanillin']),
#  ([u'HH', u'AE', u'L', u'AH', u'L', u'UW', u'Y', u'AH'], [u'hallelujah']),
#  ([u'K', u'AA', u'R', u'N', u'AH', u'T'], [u'carnett']),
#  ([u'AA', u'R', u'D'], [u'ard']),
#  ([u'IH', u'K', u'S', u'P', u'EH', u'N', u'S', u'IH', u'NG'], [u'expensing']),
#  ([u'K', u'W', u'AA', u'L', u'K', u'AA', u'M', u'Z'], [u"qualcomm's"]),
#  ([u'M', u'AA', u'HH', u'ER', u'AA', u'ZH', u'AH'], [u'maharaja']),
#  ([u'K', u'AH', u'N', u'T', u'EY', u'N', u'IH', u'NG'], [u'containing']),
#  ([u'N', u'AA', u'Z', u'AA', u'R'], [u'nazar']),
#  ([u'V', u'Y', u'UW', u'ER', u'SH', u'IH', u'P'], [u'viewership']),
#  ([u'W', u'AO', u'R', u'Z'], [u"war's", u'wars', u"wars'"]),
#  ([u'AE', u'M', u'B', u'ER', u'G', u'IY'], [u'amburgey']),
#  ([u'T', u'EH', u'G', u'IH', u'T', u'AO', u'F'], [u'tegethoff']),
#  ([u'P', u'UH', u'L', u'S', u'IH', u'F', u'ER'], [u'pulsipher']),
#  ([u'W', u'AO', u'R', u'T'], [u'wart']),
#  ([u'B',
#    u'R',
#    u'AO',
#    u'B',
#    u'D',
#    u'IH',
#    u'G',
#    u'N',
#    u'AE',
#    u'G',
#    u'IY',
#    u'AH',
#    u'N',
#    u'Z'],
#   [u'brobdingnagians']),
#  ([u'W', u'AO', u'R', u'P'], [u'warp']),
#  ([u'W', u'AO', u'R', u'N'], [u'warne', u'worn', u'warn']),
#  ([u'W', u'AO', u'R', u'M'], [u'warm']),
#  ([u'W', u'AO', u'R', u'K'], [u'wark']),
#  ([u'R', u'EH', u'V', u'Z'], [u'revs']),
#  ([u'W', u'AO', u'R', u'D'], [u'warde', u'ward']),
#  ([u'B', u'EY', u'R', u'AH'], [u'beira']),
#  ([u'HH', u'EH', u'V', u'IY', u'W', u'EY', u'T'], [u'heavyweight']),
#  ([u'EH', u'M', u'R', u'AH', u'L', u'D', u'Z'], [u'emeralds']),
#  ([u'M', u'IH', u'N', u'ER', u'AH', u'L'], [u'mineral']),
#  ([u'R', u'IY', u'V', u'EH', u'N', u'JH'], [u'revenge']),
#  ([u'ER', u'EH', u'N', u'D', u'S', u'IY'], [u'arendsee']),
#  ([u'T', u'AA', u'K', u'Y', u'UW', u'OW'], [u'tokuo']),
#  ([u'AH', u'T', u'EH', u'N', u'Y', u'UW', u'EY', u'T'], [u'attenuate']),
#  ([u'Y', u'AA', u'R', u'CH', u'OW', u'N'], [u'yarchoan']),
#  ([u'N', u'UW', u'Z', u'W', u'UH', u'M', u'AH', u'N'], [u'newswoman']),
#  ([u'SH', u'M', u'AO', u'L', u'Z'], [u'schmalz']),
#  ([u'P', u'R', u'AA', u'G', u'R', u'EH', u'S', u'AH', u'Z'], [u'progresses']),
#  ([u'L', u'AA', u'M', u'AA', u'K', u'IY', u'AH'], [u'lamacchia']),
#  ([u'P', u'L', u'ER', u'AE', u'L', u'IH', u'T', u'IY'], [u'plurality']),
#  ([u'AE', u'M', u'B', u'IH', u'SH', u'AH', u'N', u'Z'], [u'ambitions']),
#  ([u'R', u'IH', u'NG', u'D', u'AA', u'L'], [u'ringdahl']),
#  ([u'G', u'AH', u'Z', u'AA', u'N', u'S', u'K', u'IY', u'Z'], [u"gazonsky's"]),
#  ([u'T', u'EH', u'L', u'AH', u'D', u'AY', u'N', u'Z'], [u"teledyne's"]),
#  ([u'R', u'AE', u'K', u'S', u'T', u'ER'], [u'raxter']),
#  ([u'JH', u'IH', u'G', u'L', u'IY', u'OW'], [u'giglio']),
#  ([u'P', u'R', u'IH', u'V', u'AH', u'T'], [u'privott']),
#  ([u'M', u'AO', u'R', u'G', u'AH', u'N', u'T', u'AW', u'N'], [u'morgantown']),
#  ([u'D', u'W', u'AA', u'N'], [u'dwan']),
#  ([u'S', u'EH', u'K', u'SH', u'AH', u'N', u'IH', u'NG'], [u'sectioning']),
#  ([u'G', u'UW', u'IY'], [u'gooey']),
#  ([u'K', u'AA', u'S', u'AA', u'R', u'AH'], [u'cassara']),
#  ([u'Z', u'EH', u'L', u'AH', u'T', u'S'], [u'zelotes', u'zealots']),
#  ([u'S', u'AH', u'L', u'EH', u'K', u'T', u'S'], [u'selects']),
#  ([u'HH', u'Y', u'UW', u'M', u'IH', u'L', u'IY', u'EY', u'SH', u'AH', u'N'],
#   [u'humiliation']),
#  ([u'AO', u'R', u'L', u'AY', u'N'], [u'oehrlein']),
#  ([u'D', u'AY', u'N', u'AH', u'L', u'EH', u'K', u'T', u'R', u'AH', u'N'],
#   [u'dynalectron']),
#  ([u'M', u'EH', u'N', u'AO', u'R', u'D'], [u'mainord']),
#  ...]

# %%
class DecodeInfo:
    def __init__(self, w_h = [], p_w = [], orig = None):
        if not orig:
            self.word_hist = deepcopy(w_h)
            self.partial_word = deepcopy(p_w)
            self.tree = MT.search_tree
        else:
            self.word_hist = deepcopy(orig.word_hist)
            self.partial_word = deepcopy(orig.partial_word)
            self.tree = orig.tree
    
    def __hash__(self):
        return hash(" ".join(self.word_hist) + "|" + " ".join(self.partial_word))

    def __eq__(self, other):
        return (self.word_hist, self.partial_word) == (other.word_hist, other.partial_word)
    
    def empty(self):
        return not (self.word_hist or self.partial_word)
    
    def last_phoneme(self):
        if not self.partial_word:
            return partial_word[-1]
        
        elif not self.word_hist:
            #gives last phoneme of last word
            last_word = self.word_hist[-1]
            
            #arpabet is word to phoneme dictionary, stresses removed
            return MT.arpabet[last_word][-1]
        else:
            return None
            
    def one_fewer(self):
        if not self.partial_word:
            return DecodeInfo(w_h = self.word_hist, p_w = self.partial_word[:-1])
        elif not self.word_hist:
            last_word = self.word_hist[-1]
            last_phons = MT.arpabet[last_word]
            return DecodeInfo(w_h = self.word_hist[:-1], p_w = self.partial_word[:-1])
        else:
            return None
    
    def add_phon(self, new_phon):
        self.partial_word.append(new_phon)
        self.tree = self.tree.lookup([new_phon])
        if self.tree == None:
            return False
        
        else:
            return True

# %%
def get_best_paths(B, pr_b, pr_nb, width, time):
    def get_prob(y):
        return pr_b[time][y] + pr_nb[time][y]
    
    return sorted(B, key=get_prob, reverse=True)[:width]


def beam_search(T, p_ctc, p_lang, width, beta):

    pr_nb = [{}]*(T+1)
    pr_b = [{}]*(T+1)
    
    #extension probability of adding a phoneme k
    def p_ext(k, y, t):
        p_last = pr_nb[t-1][y]
        if y.last() != k:
            p_last += pr_b[t-1][y]
        return times([p_ctc(k,t), power(p_trans(k, y), beta), p_last])
    
    #derived phoneme transition prob from language model
    def p_trans(k, y):
        if y.tree.lookup([k]) == None:
            return 0.
        
        denom = np.sum(np.asarray([p_lang(x, y) for x in y.tree.get_leaves()]))
        numer = np.sum(np.asarray([p_lang(x, y) for x in y.tree.lookup([k]).get_leaves()]))
        return divide(numer, denom)
    
    #penalty probability for converting to a homophone
    def p_homophone(word, y):
        denom = np.sum(np.asarray([p_lang(x, y) for x in y.tree.get_leaves()]))
        numer = p_lang(word, y)
        return divide(numer, denom)
    #initialising non-blank prob
    pr_nb[0][DecodeInfo()] = 1
    
    #most probable sequences
    B = [DecodeInfo()]
    
    for t in range(1, T+1):
        B_hat = get_best_paths(B, pr_b, pr_nb, width, t-1)
        B = []
        for y in B_hat:
            if not y.empty():
                pr_nb[t][y] = times([pr_nb[t-1][y], p_ctc(y.last_phoneme(), t)])
                if y.one_fewer() in B_hat:
                    pr_nb[t][y] += p_trans(y.last_phoneme(), y.one_fewer(), t)
            
            pr_b[t][y] = times(pr_b[t-1][y], p_ctc("-", t))
            
            B.append(y)
            for k in MT.phonemes:
                
                #if adding a phoneme k is valid
                if k in y.tree.branches:
                    
                    pr_plus = p_trans(k, y, t)
                    
                    #initialising y_new = y+k
                    y_new = DecodeInfo(orig = y)
                    y_new.add_phoneme(k)
                    
                    conversion_penalty_prob = 0.
                    #handles conversion from phoneme string to word
                    for word in y_new.tree.leaf:
                        
                        #converted_y converts phoneme part of y_new into a new word
                        converted_y = DecodeInfo()
                        converted_y.word_hist = deepcopy(y_new.word_hist).append(word)
                        
                        pr_b[t][converted_y] = 0.
                        pr_nb[t][converted_y] = times(pr_plus, power(p_homophone(word, y_new), beta))
                        B.append(converted_y)
                        conversion_penalty_prob += p_homophone(word, y_new)

                    #penalises non-converted string
                    pr_nb[t][y_new] = times(pr_plus, power(conversion_penalty_prob, beta))
                    B.append(y_new)

    return get_best_paths(B, pr_b, pr_nb, 1)

# %%
def beam_search():
    # Iterate over input timesteps
    
    
    for t in range(1, T+1):

        # Consider all of the (w,p) pairs which were candidates given data up to time t-1
        # and compute the probabilities of 'some' new strings given data up to time t
        # 'some' = the current strings and 1-phoneme extensions of them
        for (w,p) in Z[t-1]:
            
            # We need to compute:
            
            # 1. p_nb[t][(w,p)]
            # 2. p_b[t][(w,p)]
            # 3. p_nb[t][(w,p + k)] for all k not blank. Remembering that this may lead to a new word.
           
            # Consider the extension by a blank phoneme
            p_nb[t][(w,p)] = p_nb[t-1][(w,p)] + char_probs[t, alphabet[(w,p)[-1]]] if (w,p)!=("","") else None # plus some other stuff???
            p_b[t][(w,p)] =  p[t-1][(w,p)] + char_probs[t, alphabet["-"]]
        
            # Consider extensions of the uncontracted thing by one phoneme
            for k in phons[:-1]:
                
                # When the extension definitely adds a phoneme to the contraction
                # all the probs are nb because we aren't adding blank!
                if k!="-" and k != (w,p)[-1]:

                    # if p+k can be read as a word v, compute the probability of (wv,0) using the lm
                    # for every such v
                    # Note that (-p_w_p_star[(w,p)])*alpha exactly cancels the same term in a prev computation of p[t-1][(w,p)]
                    # This is because (unlogarithmed) p[t-1] can be factored into acoustic and language factors
                    # where exp(p_w_p_star[(w,p)]*alpha) is the language factor
                    # The new language model factor is just the lm evaluated on v and the sentence
                    for h in phonemes_to_homophones(p+" "+k):
                        p_nb[t][(w+" "+h, "")] = char_probs[t, alphabet[k]] \
                                                    + p[t-1][(w,p)]   \
                                                    + (lm(h, w)-p_w_p_star[(w,p)]) * alpha
                        
                        p_b[t][(w+" "+h, "")] =  None
                              
                    # Compute the probability of (w,p+k) under the language model, NOT CONSIDERING THE ACOUSTIC MODEL
                    # This is the sum of probabilities of wx where p is a strict prefix of every x
                    p_w_p_star[(w, p+k)] = get_p_w_p_star(w, p+k)
                            
                    p_nb[t][(w,p+k)] = char_probs[t, alphabet[k]] \
                                        + p[t-1][(w,p)]   \
                                        + (p_w_p_star[(w,p+k)]-p_w_p_star[(w,p)]) * alpha
                            
                # When extension is the same as the final phoneme
                # the extension only extends y if the final phoneme in the uncontracted thing is blank
                elif k!="-" and k==(w,p)[-1]:
                    p_nb[t][(w,p+k)] = char_probs[t, alphabet[k]] \
                                        + p_b[t-1][(w,p)] \
                                        + (p_w_p_star[(w,p+k)]-p_w_p_star[(w,p)]) * alpha 
                else: # k == "-"
                    continue
                
            # Set the probability of a string given input data up to time t as the sum of the marginals over t'th model out
            p[t] = {y: np.log(np.exp(p_b[t][y]) + np.exp(p_nb[t][y])) for y in p_b[t].keys()}
            # Take the top k strings 
            Z[t] = top_keys(p[t], n_paths, beta)
    return Z[T]
# Out:
# True

# %%
nltk.corpus.cmudict.dict()["today"]
# Out:
# [[u'T', u'AH0', u'D', u'EY1'], [u'T', u'UW0', u'D', u'EY1']]

# %%
test_dict = {}
list_ = [test_dict]
test_dict[1] = 2
list_
# Out:
# [{1: 2}]

# %%
b = [1,2,3]

# %%
a = b
a[1] = 5
b
# Out:
# [1, 5, 3]
