# %%
# import tensorflow as tf
# sess = tf.Session()
import itertools
import keras
from keras import backend as K
# K.set_session(sess)
import h5py

from keras.models import Model
from keras.layers import Dense, LSTM, Input, Embedding, GRU, Masking, Dropout, Lambda, Flatten, concatenate, Conv1D, Activation
from keras.layers.normalization import BatchNormalization
from keras.optimizers import SGD, Adam
from keras.preprocessing.sequence import pad_sequences

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import cm

# import pandas 

from process_data import *
from model_saving import load_model
import os
# from n_gram_lm import *
import librosa
import kenlm
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/cpu:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16688641422960043501
# ]

# %%
# Problem parameters
max_input_len = 500
max_label_len = 180
max_ratio = 7
n_energies = 20
n_phonemes = 39+1 # 39 phonemes, 1 blank
blank_idx = n_phonemes - 1
blank_idx = n_phonemes - 1

# %%
model_name = "densenet_phon_nospace_b3.l5.f128.k7.relu"

# %%
model, highest_epoch = load_model(model_name, mode="best")
# Out:
# Loading model densenet_phon_nospace_b3.l5.f128.k7.relu
# Compiling...
# Looking for weight files with mode "best"
# File densenet_phon_nospace_b3.l5.f128.k7.relu-8-41.4200063095.hdf5 contains weights after 8 epochs achieving validation loss: 41.4200063095
# File densenet_phon_nospace_b3.l5.f128.k7.relu-13-38.06016676.hdf5 contains weights after 13 epochs achieving validation loss: 38.06016676
# File densenet_phon_nospace_b3.l5.f128.k7.relu-16-38.9010786096.hdf5 contains weights after 16 epochs achieving validation loss: 38.9010786096
# File densenet_phon_nospace_b3.l5.f128.k7.relu-1-63.4348470576.hdf5 contains weights after 1 epochs achieving validation loss: 63.4348470576
# File densenet_phon_nospace_b3.l5.f128.k7.relu-3-53.978602621.hdf5 contains weights after 3 epochs achieving validation loss: 53.978602621
# File densenet_phon_nospace_b3.l5.f128.k7.relu-4-47.3478324621.hdf5 contains weights after 4 epochs achieving validation loss: 47.3478324621
# File densenet_phon_nospace_b3.l5.f128.k7.relu-0-81.0895705597.hdf5 contains weights after 0 epochs achieving validation loss: 81.0895705597
# File densenet_phon_nospace_b3.l5.f128.k7.relu-3-48.3601631543.hdf5 contains weights after 3 epochs achieving validation loss: 48.3601631543
# File densenet_phon_nospace_b3.l5.f128.k7.relu-10-40.3903683821.hdf5 contains weights after 10 epochs achieving validation loss: 40.3903683821
# File densenet_phon_nospace_b3.l5.f128.k7.relu-7-41.3961968636.hdf5 contains weights after 7 epochs achieving validation loss: 41.3961968636
# File densenet_phon_nospace_b3.l5.f128.k7.relu-12-39.5094724111.hdf5 contains weights after 12 epochs achieving validation loss: 39.5094724111
# File densenet_phon_nospace_b3.l5.f128.k7.relu-13-39.4384019418.hdf5 contains weights after 13 epochs achieving validation loss: 39.4384019418
# File densenet_phon_nospace_b3.l5.f128.k7.relu-14-37.2627473578.hdf5 contains weights after 14 epochs achieving validation loss: 37.2627473578
# File densenet_phon_nospace_b3.l5.f128.k7.relu-5-45.662668072.hdf5 contains weights after 5 epochs achieving validation loss: 45.662668072
# File densenet_phon_nospace_b3.l5.f128.k7.relu-6-44.037959136.hdf5 contains weights after 6 epochs achieving validation loss: 44.037959136
# File densenet_phon_nospace_b3.l5.f128.k7.relu-2-56.7354897623.hdf5 contains weights after 2 epochs achieving validation loss: 56.7354897623
# File densenet_phon_nospace_b3.l5.f128.k7.relu-15-37.0718388299.hdf5 contains weights after 15 epochs achieving validation loss: 37.0718388299
# File densenet_phon_nospace_b3.l5.f128.k7.relu-11-40.03274731.hdf5 contains weights after 11 epochs achieving validation loss: 40.03274731
# File densenet_phon_nospace_b3.l5.f128.k7.relu-9-41.3177427806.hdf5 contains weights after 9 epochs achieving validation loss: 41.3177427806
# Best weights are from densenet_phon_nospace_b3.l5.f128.k7.relu-15-37.0718388299.hdf5
# Loading weights...
# Done

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# mfccs (InputLayer)               (None, 500, 20)       0
# ____________________________________________________________________________________________________
# conv1d_1 (Conv1D)                (None, 500, 128)      18048       mfccs[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 500, 128)      512         conv1d_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 500, 128)      0           batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 500, 148)      0           activation_1[0][0]
#                                                                    mfccs[0][0]
# ____________________________________________________________________________________________________
# conv1d_2 (Conv1D)                (None, 500, 128)      132736      concatenate_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 500, 128)      512         conv1d_2[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 500, 128)      0           batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 500, 276)      0           activation_2[0][0]
#                                                                    concatenate_1[0][0]
# ____________________________________________________________________________________________________
# conv1d_3 (Conv1D)                (None, 500, 128)      247424      concatenate_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 500, 128)      512         conv1d_3[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 500, 128)      0           batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# concatenate_3 (Concatenate)      (None, 500, 404)      0           activation_3[0][0]
#                                                                    concatenate_2[0][0]
# ____________________________________________________________________________________________________
# conv1d_4 (Conv1D)                (None, 500, 128)      362112      concatenate_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 500, 128)      512         conv1d_4[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 500, 128)      0           batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# concatenate_4 (Concatenate)      (None, 500, 532)      0           activation_4[0][0]
#                                                                    concatenate_3[0][0]
# ____________________________________________________________________________________________________
# conv1d_5 (Conv1D)                (None, 500, 128)      476800      concatenate_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 500, 128)      512         conv1d_5[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 500, 128)      0           batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# concatenate_5 (Concatenate)      (None, 500, 660)      0           activation_5[0][0]
#                                                                    concatenate_4[0][0]
# ____________________________________________________________________________________________________
# conv1d_6 (Conv1D)                (None, 500, 128)      591488      concatenate_5[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNorm (None, 500, 128)      512         conv1d_6[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 500, 128)      0           batch_normalization_6[0][0]
# ____________________________________________________________________________________________________
# concatenate_6 (Concatenate)      (None, 500, 788)      0           activation_6[0][0]
#                                                                    concatenate_5[0][0]
# ____________________________________________________________________________________________________
# conv1d_7 (Conv1D)                (None, 500, 128)      706176      concatenate_6[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_7 (BatchNorm (None, 500, 128)      512         conv1d_7[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 500, 128)      0           batch_normalization_7[0][0]
# ____________________________________________________________________________________________________
# concatenate_7 (Concatenate)      (None, 500, 916)      0           activation_7[0][0]
#                                                                    concatenate_6[0][0]
# ____________________________________________________________________________________________________
# conv1d_8 (Conv1D)                (None, 500, 128)      820864      concatenate_7[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_8 (BatchNorm (None, 500, 128)      512         conv1d_8[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 500, 128)      0           batch_normalization_8[0][0]
# ____________________________________________________________________________________________________
# concatenate_8 (Concatenate)      (None, 500, 1044)     0           activation_8[0][0]
#                                                                    concatenate_7[0][0]
# ____________________________________________________________________________________________________
# conv1d_9 (Conv1D)                (None, 500, 128)      935552      concatenate_8[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_9 (BatchNorm (None, 500, 128)      512         conv1d_9[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 500, 128)      0           batch_normalization_9[0][0]
# ____________________________________________________________________________________________________
# concatenate_9 (Concatenate)      (None, 500, 1172)     0           activation_9[0][0]
#                                                                    concatenate_8[0][0]
# ____________________________________________________________________________________________________
# conv1d_10 (Conv1D)               (None, 500, 128)      1050240     concatenate_9[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_10 (BatchNor (None, 500, 128)      512         conv1d_10[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 500, 128)      0           batch_normalization_10[0][0]
# ____________________________________________________________________________________________________
# concatenate_10 (Concatenate)     (None, 500, 1300)     0           activation_10[0][0]
#                                                                    concatenate_9[0][0]
# ____________________________________________________________________________________________________
# conv1d_11 (Conv1D)               (None, 500, 128)      1164928     concatenate_10[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_11 (BatchNor (None, 500, 128)      512         conv1d_11[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 500, 128)      0           batch_normalization_11[0][0]
# ____________________________________________________________________________________________________
# concatenate_11 (Concatenate)     (None, 500, 1428)     0           activation_11[0][0]
#                                                                    concatenate_10[0][0]
# ____________________________________________________________________________________________________
# conv1d_12 (Conv1D)               (None, 500, 128)      1279616     concatenate_11[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_12 (BatchNor (None, 500, 128)      512         conv1d_12[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, 500, 128)      0           batch_normalization_12[0][0]
# ____________________________________________________________________________________________________
# concatenate_12 (Concatenate)     (None, 500, 1556)     0           activation_12[0][0]
#                                                                    concatenate_11[0][0]
# ____________________________________________________________________________________________________
# conv1d_13 (Conv1D)               (None, 500, 128)      1394304     concatenate_12[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_13 (BatchNor (None, 500, 128)      512         conv1d_13[0][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, 500, 128)      0           batch_normalization_13[0][0]
# ____________________________________________________________________________________________________
# concatenate_13 (Concatenate)     (None, 500, 1684)     0           activation_13[0][0]
#                                                                    concatenate_12[0][0]
# ____________________________________________________________________________________________________
# conv1d_14 (Conv1D)               (None, 500, 128)      1508992     concatenate_13[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_14 (BatchNor (None, 500, 128)      512         conv1d_14[0][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, 500, 128)      0           batch_normalization_14[0][0]
# ____________________________________________________________________________________________________
# concatenate_14 (Concatenate)     (None, 500, 1812)     0           activation_14[0][0]
#                                                                    concatenate_13[0][0]
# ____________________________________________________________________________________________________
# conv1d_15 (Conv1D)               (None, 500, 128)      1623680     concatenate_14[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_15 (BatchNor (None, 500, 128)      512         conv1d_15[0][0]
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, 500, 128)      0           batch_normalization_15[0][0]
# ____________________________________________________________________________________________________
# concatenate_15 (Concatenate)     (None, 500, 1940)     0           activation_15[0][0]
#                                                                    concatenate_14[0][0]
# ____________________________________________________________________________________________________
# conv1d_16 (Conv1D)               (None, 500, 40)       543240      concatenate_15[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_16 (BatchNor (None, 500, 40)       160         conv1d_16[0][0]
# ____________________________________________________________________________________________________
# phoneme_probs (Activation)       (None, 500, 40)       0           batch_normalization_16[0][0]
# ____________________________________________________________________________________________________
# labels (InputLayer)              (None, 180)           0
# ____________________________________________________________________________________________________
# input_lens (InputLayer)          (None, 1)             0
# ____________________________________________________________________________________________________
# label_lens (InputLayer)          (None, 1)             0
# ____________________________________________________________________________________________________
# ctc (Lambda)                     (None, 1)             0           phoneme_probs[0][0]
#                                                                    labels[0][0]
#                                                                    input_lens[0][0]
#                                                                    label_lens[0][0]
# ====================================================================================================
# Total params: 12,864,040
# Trainable params: 12,860,120
# Non-trainable params: 3,920
# ____________________________________________________________________________________________________

# %%
# inputs, outputs, ids = get_test_data(n_phonemes, max_label_len, max_input_len)

# # print inputs_valid.keys()
# X = inputs["mfccs"]
# input_lengths= inputs["input_lens"]
# y= inputs["labels"]
# label_lengths= inputs["label_lens"]
D = nltk.corpus.cmudict.dict()

# label = code_label("what is the phone number", D)
wave_files = ["akuan_phone_number.wav.1","peter_phone_number.wav.1"]

mfccs = []
labels = []
label_lens = []
input_lens = []

for path in wave_files:
    wave, sr = librosa.load(path, mono=True, sr=None)
    mfcc = librosa.feature.mfcc(wave, sr=16000).T # transpose because librosa returns with time axis last instead of first
    label = code_label("what is the phone number", D)
    label_len = len(label)
    input_len = mfcc.shape[0]
    labels.append(label) 
    mfccs.append(mfcc) 
    label_lens.append(label_len) 
    input_lens.append(input_len)
input_lens = np.asarray(input_lens)
label_lens = np.asarray(label_lens)

# %%
y = keras.preprocessing.sequence.pad_sequences(labels, 
                                                           maxlen=max_label_len, 
                                                           dtype='int32',
                                                           padding='post', 
                                                           truncating='post', 
                                                           value=-1)
X = keras.preprocessing.sequence.pad_sequences(mfccs, 
                                               maxlen=max_input_len, 
                                               dtype='float32',
                                               padding='post', 
                                               truncating='post', 
                                               value=0.)
inputs = {'mfccs': X,
      'labels': y,
      'input_lens': np.asarray(input_lens),
      'label_lens': np.asarray(label_lens)}

# %%
ctc_costs, phoneme_probs = model.predict(inputs)
print np.mean(ctc_costs)
sample = phoneme_probs[0, :input_lens[0]]
print sample
# Out:
# 17.2006
# [[  7.24258825e-06   1.82294098e-05   7.07003492e-05 ...,   5.13060695e-05
#     1.13199228e-07   9.98108983e-01]
#  [  3.39145590e-05   5.21910442e-05   1.07139123e-04 ...,   7.91624461e-06
#     8.29175928e-09   9.98802781e-01]
#  [  2.76470546e-05   1.00591269e-05   7.11629182e-05 ...,   3.15317993e-05
#     3.95454514e-08   9.99078512e-01]
#  ...,
#  [  7.36946006e-08   7.46229432e-07   3.32463969e-06 ...,   2.40158670e-06
#     7.31329663e-08   9.99774754e-01]
#  [  1.21532224e-07   3.80972642e-06   2.31471472e-06 ...,   6.60706337e-06
#     1.69176786e-07   9.99795735e-01]
#  [  6.42171116e-08   3.18352841e-06   3.97072199e-06 ...,   7.01492309e-06
#     5.52374217e-08   9.99806345e-01]]

# %%
np.save("../decoder/phoneme_probs", sample)

# %%
checking_idx = 1
#sample_id = ids[checking_idx]

sample_probs = phoneme_probs[checking_idx]
sample_input_length = input_lens[checking_idx]
sample_label_length = label_lens[checking_idx]
sample_X = X[checking_idx]

plt.figure(figsize=(20,3))
plt.plot(sample_probs[:sample_input_length]);
fig, ax = plt.subplots(figsize=(40,100))
mfcc_data= np.swapaxes(sample_X[:input_lens[checking_idx], ], 0 ,1)
cax = ax.imshow(mfcc_data, interpolation='nearest' , origin='lower')

# %%
# print "Sample id: {}".format(sample_id)
print
# Try the argmax acoustic-only decoder
print "Argmax phonemes:"
phonemes = interpret_probs(sample_probs[:sample_input_length], ignore_blanks = False)
print "".join([x for x in phonemes if x!="-"])
# Print the 'actual' text
print


print "Actual text :"
phonemes =  obtain_phonemes("what is the phone number".split(), D)
print "".join(phonemes)
# 6319-275224-0019.flac

print "Normalized loss:"
print ctc_costs[checking_idx]
# Out:
# Argmax phonemes:
# WAHTIHZDHAEOWNAHMDHAH
#
# Actual text :
# WAHTIHZDHAHFOWNNAHMBER
# Normalized loss:
# [ 16.35684586]

# %%
phoneme_probs.shape
# Out:
# (2, 500, 40)

# %%
import tensorflow as tf

phoneme_probs_ = K.variable(phoneme_probs)#K.placeholder((None, max_input_len, n_phonemes), name="phoneme_probs")
input_lens_ = K.variable(input_lens)#K.placeholder(name='input_length',shape=(None, 1), dtype='int64')
top_paths, logp = K.ctc_decode(y_pred=phoneme_probs_, 
                               input_length=input_lens_, 
                               greedy=False, 
                               beam_width=10**4, 
                               top_paths=1000)

# print X_.shape
# print input_lengths_.shape
sess = tf.Session()
sess.run(tf.global_variables_initializer())
P, L = sess.run([top_paths,logp])

# %%
L
# Out:
# array([[ 2.17926192,  2.13937426,  1.77027333, ..., -1.07142973,
#         -1.07148933, -1.07177651],
#        [ 2.17926192,  2.13937426,  1.77027333, ..., -1.07142973,
#         -1.07148933, -1.07177651]], dtype=float32)

# %%
np.savez("../1k_paths", *P)

# %%
sample_id
# Out:
# '2961-960-0017.flac'

# %%
P_check = P[0][checking_idx]
print P_check.shape
phon_check = code_to_phonemes([x for x in P_check if x!=-1])
# print phon_check
# assert phon_check == [x for x in phonemes if x!="-"]
print "".join([x for x in phon_check if x!="-"])
print "".join([x for x in phonemes if x!="-"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-9aee4cf1ed8c> in <module>()
# ----> 1 P_check = P[0][checking_idx]
#       2 print P_check.shape
#       3 phon_check = code_to_phonemes([x for x in P_check if x!=-1])
#       4 # print phon_check
#       5 # assert phon_check == [x for x in phonemes if x!="-"]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
cmudict = nltk.corpus.cmudict.dict()
language = cmudict.keys()

# %%
cmudict["don't"]
# Out:
# [[u'D', u'OW1', u'N', u'T'], [u'D', u'OW1', u'N']]

# %%
n_paths = 100
alpha = 1.25
beta = 0.1            
step_size = 5
candidates = beam_search_word(sample_probs, sample_input_length, language_score, alpha, beta, n_paths, step_size)
# Out:
# Starting beam search with input of length 258 ...
# Reached t = 0
# Found top 100 candidates
# Checking extensions of "" which has current score 0.0
# [u'fawn']
# [u'F', u'AO', u'N']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-0be0d92ca8d1> in <module>()
#       3 beta = 0.1
#       4 step_size = 5
# ----> 5 candidates = beam_search_word(sample_probs, sample_input_length, language_score, alpha, beta, n_paths, step_size)
#
# <ipython-input-47-d42334592861> in beam_search_word(phoneme_probs, input_length, language_score, alpha, beta, n_paths, step_size)
#      30                 print new_phonemes
#      31                 # Add the language score and the length bonus
# ---> 32                 new_score = acoustic_score(new_phonemes, phoneme_probs, t)                             + alpha*language_score(s_new)                             + beta*len(s_new_list)
#      33                 # Add the new sentence to the candidates if it is better than its parent
#      34                 if new_score >= score:
#
# <ipython-input-46-04ca29c2763e> in acoustic_score(phoneme_list, phoneme_probs, t)
#      22               "the_labels": code_phonemes(phoneme_list),
#      23               "label_length": len(phoneme_list)}
# ---> 24     ctc = cost_getter.predict(inputs) # this should be the negative log probability
#      25     return ctc
#
# /home/ubuntu/anaconda2/envs/transcriber/lib/python2.7/site-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose)
#    1497         x = _standardize_input_data(x, self._feed_input_names,
#    1498                                     self._feed_input_shapes,
# -> 1499                                     check_batch_axis=False)
#    1500         if self.stateful:
#    1501             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# /home/ubuntu/anaconda2/envs/transcriber/lib/python2.7/site-packages/keras/engine/training.pyc in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     111     for i in range(len(names)):
#     112         array = arrays[i]
# --> 113         if len(array.shape) == 1:
#     114             array = np.expand_dims(array, 1)
#     115             arrays[i] = array
#
# AttributeError: 'list' object has no attribute 'shape'
